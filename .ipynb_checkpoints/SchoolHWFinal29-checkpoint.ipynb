# %%
import pandas as pd

# %%
school_data_to_load =  "C:/Users/User/School.csv"
student_data_to_load = "C:/Users/User/Student.csv"

# %%
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# %%
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
total_numbers_schools= school_data_complete["School ID"].nunique()
Total_students= school_data_complete["Student ID"].count()
total_budget= school_data_complete["budget"].unique().sum()
Average_Math_score= (school_data_complete["math_score"]).mean()
Average_Reading_score= (school_data_complete["reading_score"]).mean()
Total_Passing_rate= (Average_Math_score+Average_Reading_score)/2
Passing_Math=(school_data_complete['math_score'].loc[school_data_complete["math_score"]>=70].count()/Total_students)*100
Passing_Reading= (school_data_complete["reading_score"].loc[school_data_complete["reading_score"]>=70].count()/Total_students)*100

# %%
Distirict_Summary = pd.DataFrame({"Total Schools":[total_numbers_schools],
                           "Total Students":[Total_students], 
                           "Total Budget": [total_budget], 
                           "Average Math Score": [Average_Math_score] ,
                                 "Average Reading Score":[Average_Reading_score],
                                 "%Passing Math":[Passing_Math],
                                  "%Passing Reading":[Passing_Reading],
                                  "%Overall Passing Rate":[Total_Passing_rate]})
Distirict_Summary.style.format({'Total Budget':"${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_ff3d34e2_5c05_11ea_a6e6_e86f3895b9d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Schools</th>        <th class="col_heading level0 col1" >Total Students</th>        <th class="col_heading level0 col2" >Total Budget</th>        <th class="col_heading level0 col3" >Average Math Score</th>        <th class="col_heading level0 col4" >Average Reading Score</th>        <th class="col_heading level0 col5" >%Passing Math</th>        <th class="col_heading level0 col6" >%Passing Reading</th>        <th class="col_heading level0 col7" >%Overall Passing Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ff3d34e2_5c05_11ea_a6e6_e86f3895b9d2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ff3d34e2_5c05_11ea_a6e6_e86f3895b9d2row0_col0" class="data row0 col0" >15</td>
# ...

# %%
school_data_complete = pd.merge(student_data, school_data, how="outer", on=["school_name", "school_name"])
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
schoolsummary =school_data_complete[["school_name", "type", "Student ID", "budget", "math_score", "reading_score"]]

# %%
group = schoolsummary.groupby(["school_name","type","budget"])["school_name"].agg(['count'])

# %%
group.reset_index(inplace=True)

# %%
group
# Out:
#               school_name      type   budget  count
# 0      Bailey High School  District  3124928   4976
# 1     Cabrera High School   Charter  1081356   1858
# 2    Figueroa High School  District  1884411   2949
# 3        Ford High School  District  1763916   2739
# 4     Griffin High School   Charter   917500   1468
# 5   Hernandez High School  District  3022020   4635
# 6      Holden High School   Charter   248087    427
# 7       Huang High School  District  1910635   2917
# 8     Johnson High School  District  3094650   4761
# 9        Pena High School   Charter   585858    962
# 10  Rodriguez High School  District  2547363   3999
# 11    Shelton High School   Charter  1056600   1761
# 12     Thomas High School   Charter  1043130   1635
# 13     Wilson High School   Charter  1319574   2283
# 14     Wright High School   Charter  1049400   1800

# %%
group2 = schoolsummary.groupby(["school_name"])

# %%
group_ = group2.mean()
group_
# Out:
#                        Student ID     budget  math_score  reading_score
# school_name
# Bailey High School        20358.5  3124928.0   77.048432      81.033963
# Cabrera High School       16941.5  1081356.0   83.061895      83.975780
# Figueroa High School       4391.0  1884411.0   76.711767      81.158020
# Ford High School          36165.0  1763916.0   77.102592      80.746258
# Griffin High School       12995.5   917500.0   83.351499      83.816757
# Hernandez High School      9944.0  3022020.0   77.289752      80.934412
# Holden High School        23060.0   248087.0   83.803279      83.814988
# Huang High School          1458.0  1910635.0   76.629414      81.182722
# Johnson High School       32415.0  3094650.0   77.072464      80.966394
# Pena High School          23754.5   585858.0   83.839917      84.044699
# Rodriguez High School     28035.0  2547363.0   76.842711      80.744686
# Shelton High School        6746.0  1056600.0   83.359455      83.725724
# ...

# %%
del group_["Student ID"]

# %%
del group_["budget"]

# %%
merged = pd.merge(group, group_, on="school_name", how="outer")

# %%
merged = merged.rename(columns = {"count": "Total Students", "math_score" : "Average Math Score", "reading_score":"Average Reading Score", "type":"School Type","budget":"Total School Budget"})

# %%
merged = merged.sort_values("School Type")

# %%
merged["Per Student Budget"] = merged["Total School Budget"]/merged["Total Students"]

# %%
merged
# Out:
#               school_name School Type  Total School Budget  Total Students  \
# 1     Cabrera High School     Charter              1081356            1858
# 4     Griffin High School     Charter               917500            1468
# 6      Holden High School     Charter               248087             427
# 9        Pena High School     Charter               585858             962
# 11    Shelton High School     Charter              1056600            1761
# 12     Thomas High School     Charter              1043130            1635
# 13     Wilson High School     Charter              1319574            2283
# 14     Wright High School     Charter              1049400            1800
# 0      Bailey High School    District              3124928            4976
# 2    Figueroa High School    District              1884411            2949
# 3        Ford High School    District              1763916            2739
# ...

# %%
reading_view = school_data_complete [school_data_complete["reading_score"] >69]

# %%
group_view = reading_view.groupby("school_name")["reading_score"].agg('count')

# %%
group_view
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1591
# Wilson High School       2204
# Wright High School       1739
# Name: reading_score, dtype: int64

# %%
merged2 = pd.merge(merged, group_view, on="school_name", how="outer")

# %%
merged2
# Out:
#               school_name School Type  Total School Budget  Total Students  \
# 0     Cabrera High School     Charter              1081356            1858
# 1     Griffin High School     Charter               917500            1468
# 2      Holden High School     Charter               248087             427
# 3        Pena High School     Charter               585858             962
# 4     Shelton High School     Charter              1056600            1761
# 5      Thomas High School     Charter              1043130            1635
# 6      Wilson High School     Charter              1319574            2283
# 7      Wright High School     Charter              1049400            1800
# 8      Bailey High School    District              3124928            4976
# 9    Figueroa High School    District              1884411            2949
# 10       Ford High School    District              1763916            2739
# ...

# %%
merged2["% Passsing Reading"] = (merged2["reading_score"]/merged2["Total Students"])*100

# %%
merged2
# Out:
#               school_name School Type  Total School Budget  Total Students  \
# 0     Cabrera High School     Charter              1081356            1858
# 1     Griffin High School     Charter               917500            1468
# 2      Holden High School     Charter               248087             427
# 3        Pena High School     Charter               585858             962
# 4     Shelton High School     Charter              1056600            1761
# 5      Thomas High School     Charter              1043130            1635
# 6      Wilson High School     Charter              1319574            2283
# 7      Wright High School     Charter              1049400            1800
# 8      Bailey High School    District              3124928            4976
# 9    Figueroa High School    District              1884411            2949
# 10       Ford High School    District              1763916            2739
# ...

# %%
math_view = school_data_complete[school_data_complete["math_score"] >69]

# %%
math_view
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0                 66          79          0  District  2917  1910635
# ...

# %%
m_group_view = math_view.groupby("school_name")["math_score"].agg('count')

# %%
merged2 = pd.merge(merged2, m_group_view, on="school_name", how="outer")

# %%
merged2
# Out:
#               school_name School Type  Total School Budget  Total Students  \
# 0     Cabrera High School     Charter              1081356            1858
# 1     Griffin High School     Charter               917500            1468
# 2      Holden High School     Charter               248087             427
# 3        Pena High School     Charter               585858             962
# 4     Shelton High School     Charter              1056600            1761
# 5      Thomas High School     Charter              1043130            1635
# 6      Wilson High School     Charter              1319574            2283
# 7      Wright High School     Charter              1049400            1800
# 8      Bailey High School    District              3124928            4976
# 9    Figueroa High School    District              1884411            2949
# 10       Ford High School    District              1763916            2739
# ...

# %%
merged2["% Overall Passing Math"] = (merged2["math_score"]/merged2["Total Students"])*100

# %%
merged2
# Out:
#               school_name School Type  Total School Budget  Total Students  \
# 0     Cabrera High School     Charter              1081356            1858
# 1     Griffin High School     Charter               917500            1468
# 2      Holden High School     Charter               248087             427
# 3        Pena High School     Charter               585858             962
# 4     Shelton High School     Charter              1056600            1761
# 5      Thomas High School     Charter              1043130            1635
# 6      Wilson High School     Charter              1319574            2283
# 7      Wright High School     Charter              1049400            1800
# 8      Bailey High School    District              3124928            4976
# 9    Figueroa High School    District              1884411            2949
# 10       Ford High School    District              1763916            2739
# ...

# %%
merged2["% Overall Passing Rate"] = (merged2["% Passsing Reading"] + merged2["% Overall Passing Math"])/2

# %%
finalsummary = merged2

# %%
del finalsummary["reading_score"]
del finalsummary["math_score"]

# %%
finalsummary.head(5)
# Out:
#            school_name School Type  Total School Budget  Total Students  \
# 0  Cabrera High School     Charter              1081356            1858
# 1  Griffin High School     Charter               917500            1468
# 2   Holden High School     Charter               248087             427
# 3     Pena High School     Charter               585858             962
# 4  Shelton High School     Charter              1056600            1761
#
#    Average Math Score  Average Reading Score  Per Student Budget  \
# 0           83.061895              83.975780               582.0
# 1           83.351499              83.816757               625.0
# 2           83.803279              83.814988               581.0
# 3           83.839917              84.044699               609.0
# 4           83.359455              83.725724               600.0
#
#    % Passsing Reading  % Overall Passing Math  % Overall Passing Rate
# 0           97.039828               94.133477               95.586652
# ...

# %%
finalsummary = finalsummary[["school_name", "School Type", "Total Students", "Total School Budget", "Per Student Budget", "Average Math Score","Average Reading Score", "% Overall Passing Math", "% Passsing Reading", "% Overall Passing Rate"]]

# %%
finalsummary.rename(columns = {"% Overall Passing Math" : "% Passing Math", "% Passsing Reading":"% Passing Reading"}, inplace=True)
finalsummary.reset_index()
finalsummary.set_index("school_name")
# Out:
#                       School Type  Total Students  Total School Budget  \
# school_name
# Cabrera High School       Charter            1858              1081356
# Griffin High School       Charter            1468               917500
# Holden High School        Charter             427               248087
# Pena High School          Charter             962               585858
# Shelton High School       Charter            1761              1056600
# Thomas High School        Charter            1635              1043130
# Wilson High School        Charter            2283              1319574
# Wright High School        Charter            1800              1049400
# Bailey High School       District            4976              3124928
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Hernandez High School    District            4635              3022020
# ...

# %%
Top_Schools= finalsummary.sort_values("% Overall Passing Rate", ascending = False)
Top_Schools.reset_index()
Top_Schools.head(5)
# Out:
#            school_name School Type  Total Students  Total School Budget  \
# 0  Cabrera High School     Charter            1858              1081356
# 5   Thomas High School     Charter            1635              1043130
# 3     Pena High School     Charter             962               585858
# 1  Griffin High School     Charter            1468               917500
# 6   Wilson High School     Charter            2283              1319574
#
#    Per Student Budget  Average Math Score  Average Reading Score  \
# 0               582.0           83.061895              83.975780
# 5               638.0           83.418349              83.848930
# 3               609.0           83.839917              84.044699
# 1               625.0           83.351499              83.816757
# 6               578.0           83.274201              83.989488
#
#    % Passing Math  % Passing Reading  % Overall Passing Rate
# 0       94.133477          97.039828               95.586652
# ...

# %%
Worst_Schools = finalsummary.sort_values("% Overall Passing Rate", ascending = True)
Worst_Schools.reset_index()
Worst_Schools.head(5)
# Out:
#               school_name School Type  Total Students  Total School Budget  \
# 14  Rodriguez High School    District            3999              2547363
# 9    Figueroa High School    District            2949              1884411
# 12      Huang High School    District            2917              1910635
# 13    Johnson High School    District            4761              3094650
# 10       Ford High School    District            2739              1763916
#
#     Per Student Budget  Average Math Score  Average Reading Score  \
# 14               637.0           76.842711              80.744686
# 9                639.0           76.711767              81.158020
# 12               655.0           76.629414              81.182722
# 13               650.0           77.072464              80.966394
# 10               644.0           77.102592              80.746258
#
#     % Passing Math  % Passing Reading  % Overall Passing Rate
# ...

# %%
grade9 = school_data_complete[school_data_complete["grade"] == "9th"]
grade10 = school_data_complete[school_data_complete["grade"] == "10th"]
grade11 = school_data_complete[school_data_complete["grade"] == "11th"]
grade12 = school_data_complete[school_data_complete["grade"] == "12th"]
group9 = grade9.groupby("school_name")
group10 = grade10.groupby("school_name")
group11 = grade11.groupby("school_name")
group12 = grade12.groupby("school_name")
m1 = group9['math_score'].mean()
m2 = group10['math_score'].mean()
m3 = group11['math_score'].mean()
m4 = group12['math_score'].mean()
r1 = group9['reading_score'].mean()
r2 = group10['reading_score'].mean()
r3 = group11['reading_score'].mean()
r4 = group12['reading_score'].mean()

# %%
readsum = pd.merge(r1, r2, on="school_name", how="outer")
readsum = readsum.rename(columns = {"reading_score_x" : "9th Grade Reading Scores", "reading_score_y" : "10th Grade Reading Scores"})
mathsum = pd.merge(m1, m2, on="school_name", how="outer")
mathsum = mathsum.rename(columns = {"math_score_x" : "9th Grade Math Scores", "math_score_y" : "10th Grade Math Scores"})
readsum = pd.merge(readsum, r3, on="school_name", how="outer")
readsum = readsum.rename(columns = {"reading_score" : "11th Grade Reading Scores"})
mathsum = pd.merge(mathsum, m3, on="school_name", how="outer")
mathsum = mathsum.rename(columns = {"math_score" : "11th Grade Math Scores"})
mathsum = pd.merge(mathsum, m4, on="school_name", how="outer").rename(columns = {"math_score" : "12th Grade Math Scores"})
readsum = pd.merge(readsum, r4, on="school_name", how="outer").rename(columns = {"reading_score" : "12th Grade Reading Scores"})

# %%
mathsum
# Out:
#                        9th Grade Math Scores  10th Grade Math Scores  \
# school_name
# Bailey High School                 77.083676               76.996772
# Cabrera High School                83.094697               83.154506
# Figueroa High School               76.403037               76.539974
# Ford High School                   77.361345               77.672316
# Griffin High School                82.044010               84.229064
# Hernandez High School              77.438495               77.337408
# Holden High School                 83.787402               83.429825
# Huang High School                  77.027251               75.908735
# Johnson High School                77.187857               76.691117
# Pena High School                   83.625455               83.372000
# Rodriguez High School              76.859966               76.612500
# Shelton High School                83.420755               82.917411
# ...

# %%
readsum
# Out:
#                        9th Grade Reading Scores  10th Grade Reading Scores  \
# school_name
# Bailey High School                    81.303155                  80.907183
# Cabrera High School                   83.676136                  84.253219
# Figueroa High School                  81.198598                  81.408912
# Ford High School                      80.632653                  81.262712
# Griffin High School                   83.369193                  83.706897
# Hernandez High School                 80.866860                  80.660147
# Holden High School                    83.677165                  83.324561
# Huang High School                     81.290284                  81.512386
# Johnson High School                   81.260714                  80.773431
# Pena High School                      83.807273                  83.612000
# Rodriguez High School                 80.993127                  80.629808
# ...

# %%
bins = [0, 585, 615, 645, 675]
names = ["<$585", "$585-615", "$615-645", "$645-675"]

# %%
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data_complete['spending_bins2'] = pd.cut(school_data_complete['size'], size_bins, labels = group_names )

by_spending = school_data_complete.groupby('spending_bins2')

avg_math = by_spending['math_score'].mean()
avg_reading = by_spending['reading_score'].mean()


passread = school_data_complete[school_data_complete["reading_score"]>= 70].groupby('spending_bins2')["Student ID"].count()/by_spending["Student ID"].count()
passmath = school_data_complete[school_data_complete["math_score"]>= 70].groupby('spending_bins2')["Student ID"].count()/by_spending["Student ID"].count()

SummaryTable = pd.DataFrame({"Average Math Score" : avg_math, "Average Reading Score" : avg_reading, "%Passing Math" : passmath, "% Passing Reading":passread})

SummaryTable["%Overall Passing Rate"] = (SummaryTable["%Passing Math"] + SummaryTable["% Passing Reading"])/2

SummaryTable.style.format({"Average Math Score": '{:.1f}',
                           "Average Reading Score" : '{:.1f}',
                           '%Passing Math': '{:.1%}',
                           '% Passing Reading':'{:.1%}',
                           '%Overall Passing Rate': '{:.1%}'
                          
                          })
# Out:
# <style  type="text/css" >
# </style><table id="T_8306de80_63e1_11ea_a97a_e86f3895b9d2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Average Math Score</th>        <th class="col_heading level0 col1" >Average Reading Score</th>        <th class="col_heading level0 col2" >%Passing Math</th>        <th class="col_heading level0 col3" >% Passing Reading</th>        <th class="col_heading level0 col4" >%Overall Passing Rate</th>    </tr>    <tr>        <th class="index_name level0" >spending_bins2</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8306de80_63e1_11ea_a97a_e86f3895b9d2level0_row0" class="row_heading level0 row0" >Small (<1000)</th>
# ...

# %%
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data_complete['spending_bins'] = pd.cut(school_data_complete['budget']/school_data_complete['size'], bins, labels = names)
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
by_spending = school_data_complete.groupby('spending_bins')
avg_math = by_spending['math_score'].mean()
avg_reading = by_spending['reading_score'].mean()
passread = school_data_complete[school_data_complete["reading_score"]>= 70].groupby('spending_bins')["Student ID"].count()/by_spending["Student ID"].count()
passmath = school_data_complete[school_data_complete["math_score"]>= 70].groupby('spending_bins')["Student ID"].count()/by_spending["Student ID"].count()
# Out:
# spending_bins
# <$585       0.937029
# $585-615    0.941241
# $615-645    0.714004
# $645-675    0.662308
# Name: Student ID, dtype: float64

# %%
SummaryTable = pd.DataFrame({"Average Math Score" : avg_math, "Average Reading Score" : avg_reading, "%Passing Math" : passmath, "% Passing Reading":passread})

SummaryTable["%Overall Passing Rate"] = (SummaryTable["%Passing Math"] + SummaryTable["% Passing Reading"])/2
SummaryTable.head()
# Out:
#                Average Math Score  Average Reading Score  %Passing Math  \
# spending_bins
# <$585                   83.363065              83.964039       0.937029
# $585-615                83.529196              83.838414       0.941241
# $615-645                78.061635              81.434088       0.714004
# $645-675                77.049297              81.005604       0.662308
#
#                % Passing Reading  %Overall Passing Rate
# spending_bins
# <$585                   0.966866               0.951947
# $585-615                0.958869               0.950055
# $615-645                0.836148               0.775076
# $645-675                0.811094               0.736701

# %%
SummaryTable.style.format({"Average Math Score": '{:.1f}',
                           "Average Reading Score" : '{:.1f}',
                           '%Passing Math': '{:.1%}',
                           '% Passing Reading':'{:.1%}',
                           '%Overall Passing Rate': '{:.1%}'
                          
                          })
SummaryTable.head()
# Out:
#                Average Math Score  Average Reading Score  %Passing Math  \
# spending_bins
# <$585                   83.363065              83.964039       0.937029
# $585-615                83.529196              83.838414       0.941241
# $615-645                78.061635              81.434088       0.714004
# $645-675                77.049297              81.005604       0.662308
#
#                % Passing Reading  %Overall Passing Rate
# spending_bins
# <$585                   0.966866               0.951947
# $585-615                0.958869               0.950055
# $615-645                0.836148               0.775076
# $645-675                0.811094               0.736701

# %%
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
Scores_by_School_Type= school_data_complete.groupby("type")
Average_Math_score= Scores_by_School_Type["math_score"].mean()
Average_Reading_score= Scores_by_School_Type["reading_score"].mean()
Total_Passing_rate= (Average_Math_score+Average_Reading_score)/2
Passing_Math= school_data_complete[school_data_complete["math_score"]>=70].groupby('type')["Student ID"].count()/Scores_by_School_Type["Student ID"].count()*100
Passing_Reading= school_data_complete[school_data_complete["reading_score"]>= 70].groupby('type')["Student ID"].count()/Scores_by_School_Type["Student ID"].count()*100

Data_Frame= pd.DataFrame({"Average Math Score":[Average_Math_score],
             "Average Reading Score":[Average_Reading_score],
             "% Passing Math":[Passing_Math],
             "% Passing Reading":[Passing_Reading],
             "% Overall Passing Rate":[Total_Passing_rate]})

Data_Frame.head()
# Out:
#                                   Average Math Score  \
# 0  type
# Charter     83.406183
# District    76.9870...
#
#                                Average Reading Score  \
# 0  type
# Charter     83.902821
# District    80.9624...
#
#                                       % Passing Math  \
# 0  type
# Charter     93.701821
# District    66.5183...
#
#                                    % Passing Reading  \
# 0  type
# Charter     96.645891
# District    80.9052...
#
#                               % Overall Passing Rate
# 0  type
# Charter     83.654502
# District    78.9747...

# %%
Data_Frame
# Out:
#    index                                 Average Math Score  \
# 0      0  type
# Charter     83.406183
# District    76.9870...
#
#                                Average Reading Score  \
# 0  type
# Charter     83.902821
# District    80.9624...
#
#                                       % Passing Math  \
# 0  type
# Charter     0.937018
# District    0.665184...
#
#                                    % Passing Reading  \
# 0  type
# Charter     0.966459
# District    0.809052...
#
#                               % Overall Passing Rate
# 0  type
# Charter     83.654502
# District    78.9747...
